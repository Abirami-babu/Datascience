# %%
D1 = {"loginID":"xyz","country":"USA"}
D2 = {"firstname":"justin","lastname":"lambert"}
D1.update(D2)
print(D1)
# Out:
# {'loginID': 'xyz', 'country': 'USA', 'firstname': 'justin', 'lastname': 'lambert'}

# %%
import re
def text_match(text):
        patterns = '[a]{1}[b]?'
        if re.search(patterns,  text):
                return 'Found a match!'
        else:
                return('Not matched!')

print(text_match("ab"))
print(text_match("abc"))
print(text_match("abbc"))
print(text_match("aabbc"))
# Out:
# Found a match!
# Found a match!
# Found a match!
# Found a match!

# %%
num_list = [y for y in range(1000) if y % 13 == 0 if y % 25 == 0]
print(num_list)
# Out:
# [0, 325, 650, 975]

# %%
names = ["Sandhya Tribbiani", "Amy Geller", "Lorenzo Bing", "Susane Buffay"]
y=[]
for i in names:
  x=i.find(" ")
  i=i[:x]+'_'+i[x+1:]+'@amz.com'
  y.append(i)
print(y)
# Out:
# ['Sandhya_Tribbiani@amz.com', 'Amy_Geller@amz.com', 'Lorenzo_Bing@amz.com', 'Susane_Buffay@amz.com']
